# %% [markdown]
# Regression with Panel Data
# ===
# ---
# * First-Differend Estimator
# * Reshape Data
# * Fixed Effects Regression
# * Standard Errors for Fixed Effects Regression
# ---

# %%
library(tidyverse)
library(stargazer)
# Out:
# ─ Attaching packages ──────────────────── tidyverse 1.2.1 ─
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.4.0
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# Warning message:
# “package ‘dplyr’ was built under R version 3.5.1”Warning message:
# “package ‘stringr’ was built under R version 3.5.2”─ Conflicts ───────────────────── tidyverse_conflicts() ─
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Please cite as:
#
#  Hlavac, Marek (2018). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#  R package version 5.2.2. https://CRAN.R-project.org/package=stargazer

# %%
traffic1 <- read.csv("/Users/tino/Desktop/TA-Econometrics-II/datasets/0507/traffic1.csv")

# %%
head(traffic1) # wide format
# Out:
#   state open90 open85 dthrte90 dthrte85
# 1 AL    0      0      2.6      2.9
# 2 AK    1      0      2.1      3.2
# 3 AZ    0      0      2.5      4.4
# 4 AR    0      0      2.9      3.4
# 5 CA    1      1      2.0      2.6
# 6 CO    0      0      1.9      2.4

# %% [markdown]
# ---
# ## 1. First-Differenced Estimator
# * mutate the "comparison variables"
# * regress with comparison variables (without intercept)

# %%
traffic1 <- traffic1 %>%
    mutate(copen = open90 - open85, cdthrte = dthrte90 - dthrte85)
# pipeline operator, which is quite useful when encountering complicate data manipulation
# equal to: traffic1 <- mutate(data = traffic1, copen = open90 - open85, cdthrte = dthrte90 - dthrte85)

# %%
head(traffic1)
# Out:
#   state open90 open85 dthrte90 dthrte85 copen cdthrte
# 1 AL    0      0      2.6      2.9      0     -0.3000002
# 2 AK    1      0      2.1      3.2      1     -1.1000001
# 3 AZ    0      0      2.5      4.4      0     -1.9000001
# 4 AR    0      0      2.9      3.4      0     -0.5000000
# 5 CA    1      1      2.0      2.6      0     -0.5999999
# 6 CO    0      0      1.9      2.4      0     -0.5000001

# %%
FD <- lm(cdthrte ~ copen - 1, data = traffic1) 
# -1: without intercept

stargazer(FD, type = "text", title = "First-Differenced Estimator") 
# use "stargazer" to perform your results
# type = "text": directly show in Rstudio instead of LaTex code 
# FD estimator: coefficient = -0.97
# Out:
# First-Differenced Estimator
# ===============================================
#                         Dependent variable:
#                     ---------------------------
#                               cdthrte
# -----------------------------------------------
# copen                        -0.967***
#                               (0.354)
#
# -----------------------------------------------
# Observations                    51
# R2                             0.130
# Adjusted R2                    0.113
# Residual Std. Error       0.613 (df = 50)
# F Statistic            7.465*** (df = 1; 50)
# ===============================================
# Note:               *p<0.1; **p<0.05; ***p<0.01

# %% [markdown]
# ---
# ## 2. Reshape Data
# * wide format --> long format
# * long format: panel regression

# %%
# reshape data from wide to long
traffic1 <- traffic1 %>%
  unite(85, open85, dthrte85) %>%
  unite(90, open90, dthrte90) %>%
  gather(key = "year", value = "open_dthrte", `85`, `90`) %>%
  separate(open_dthrte, into = c("open", "dthrte"), sep = "_")
  
traffic1$year <- as.numeric(traffic1$year)
traffic1$open <- as.numeric(traffic1$open)
traffic1$dthrte <- as.numeric(traffic1$dthrte)

# %%
traffic1 # long format
# Out:
#     state year open dthrte
# 1   AL    85   0    2.9
# 2   AK    85   0    3.2
# 3   AZ    85   0    4.4
# 4   AR    85   0    3.4
# 5   CA    85   1    2.6
# 6   CO    85   0    2.4
# 7   CT    85   0    2.0
# 8   DE    85   0    2.2
# 9   DC    85   0    3.0
# 10  FL    85   0    3.4
# 11  GA    85   0    2.7
# 12  HI    85   1    2.0
# 13  ID    85   1    3.5
# 14  IL    85   1    2.3
# 15  IN    85   0    2.6
# 16  IA    85   1    2.4
# 17  KS    85   1    2.6
# 18  KY    85   0    2.6
# 19  LA    85   0    3.0
# 20  ME    85   0    2.4
# 21  MD    85   1    2.3
# 22  MA    85   0    1.9
# 23  MI    85   1    2.4
# 24  MN    85   1    2.0
# 25  MS    85   0    3.6
# 26  MO    85   0    2.6
# 27  MT    85   1    3.1
# 28  NE    85   0    2.1
# 29  NV    85   0    3.9
# 30  NH    85   0    2.6
# ⋮   ⋮     ⋮    ⋮    ⋮
# 73  MA    90   0    1.3
# 74  MI    90   1    1.9
# 75  MN    90   1    1.5
# 76  MS    90   0    3.2
# 77  MO    90   0    2.3
# 78  MT    90   1    2.5
# 79  NE    90   0    1.9
# 80  NV    90   0    3.6
# 81  NH    90   0    1.6
# 82  NJ    90   0    1.5
# 83  NM    90   1    3.1
# 84  NY    90   0    2.0
# 85  NC    90   1    2.3
# 86  ND    90   1    1.9
# 87  OH    90   0    1.8
# 88  OK    90   1    2.0
# 89  OR    90   1    2.2
# 90  PA    90   0    1.9
# 91  RI    90   0    1.3
# 92  SC    90   1    2.9
# 93  SD    90   1    2.3
# 94  TN    90   0    2.6
# 95  TX    90   0    2.0
# 96  UT    90   1    2.0
# 97  VT    90   0    1.5
# 98  VA    90   0    1.8
# 99  WA    90   1    1.9
# 100 WV    90   0    3.2
# 101 WI    90   1    1.8
# 102 WY    90   0    2.2

# %% [markdown]
# ---
# ## 3. Fixed Effects Regression
# * Fixed Effects without binary varibles
#     *
#
# * Fixed Effects with binary varibles

# %%
library(plm)
# Out:
# Warning message:
# “package ‘plm’ was built under R version 3.5.2”Loading required package: Formula
#
# Attaching package: ‘plm’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, lag, lead

# %%
FE <- plm(dthrte ~ open, data = traffic1, index = c("state", "year"), model = "within")
stargazer(FE, type = "text", title = "Fixed Effects Regression")
# Fixed Effects Regression: coefficient = -0.97
# Out:
# Fixed Effects Regression
# ========================================
#                  Dependent variable:
#              ---------------------------
#                        dthrte
# ----------------------------------------
# open                  -0.967***
#                        (0.354)
#
# ----------------------------------------
# Observations             102
# R2                      0.130
# Adjusted R2            -0.758
# F Statistic     7.465*** (df = 1; 50)
# ========================================
# Note:        *p<0.1; **p<0.05; ***p<0.01

# %%
FE.dummy <-lm(dthrte ~ open + factor(state), data = traffic1)
stargazer(FE.dummy, type = "text", title = "Fixed Effects Regression (with Binary Variables)") 
# Fixed Effects Regression (with Binary Variable): coefficient = -0.97
# Out:
# Fixed Effects Regression (with Binary Variables)
# ===============================================
#                         Dependent variable:
#                     ---------------------------
#                               dthrte
# -----------------------------------------------
# open                         -0.967***
#                               (0.354)
#
# factor(state)AL               -0.383
#                               (0.468)
#
# factor(state)AR                0.017
#                               (0.468)
#
# factor(state)AZ                0.317
#                               (0.468)
#
# factor(state)CA                0.133
#                               (0.468)
#
# factor(state)CO              -0.983**
#                               (0.468)
#
# factor(state)CT              -1.383***
#                               (0.468)
#
# factor(state)DC               -0.833*
#                               (0.468)
#
# factor(state)DE               -0.933*
#                               (0.468)
#
# factor(state)FL                0.400
#                               (0.433)
#
# factor(state)GA               -0.783
#                               (0.468)
#
# factor(state)HI               -0.017
#                               (0.468)
#
# factor(state)IA                0.083
#                               (0.468)
#
# factor(state)ID               1.033**
#                               (0.468)
#
# factor(state)IL               -0.067
#                               (0.468)
#
# factor(state)IN               -0.933*
#                               (0.468)
#
# factor(state)KS                0.183
#                               (0.468)
#
# factor(state)KY               -0.533
#                               (0.468)
#
# factor(state)LA               -0.383
#                               (0.468)
#
# factor(state)MA              -1.533***
#                               (0.468)
#
# factor(state)MD               -0.067
#                               (0.468)
#
# factor(state)ME              -1.033**
#                               (0.468)
#
# factor(state)MI               -0.017
#                               (0.468)
#
# factor(state)MN               -0.417
#                               (0.468)
#
# factor(state)MO               -0.683
#                               (0.468)
#
# factor(state)MS                0.267
#                               (0.468)
#
# factor(state)MT                0.633
#                               (0.468)
#
# factor(state)NC                0.533
#                               (0.468)
#
# factor(state)ND               -0.117
#                               (0.468)
#
# factor(state)NE              -1.133**
#                               (0.468)
#
# factor(state)NH              -1.033**
#                               (0.468)
#
# factor(state)NJ              -1.433***
#                               (0.468)
#
# factor(state)NM               1.000**
#                               (0.433)
#
# factor(state)NV                0.617
#                               (0.468)
#
# factor(state)NY              -0.983**
#                               (0.468)
#
# factor(state)OH              -1.183**
#                               (0.468)
#
# factor(state)OK                0.083
#                               (0.468)
#
# factor(state)OR                0.333
#                               (0.468)
#
# factor(state)PA              -0.983**
#                               (0.468)
#
# factor(state)RI              -1.433***
#                               (0.468)
#
# factor(state)SC               1.033**
#                               (0.468)
#
# factor(state)SD                0.133
#                               (0.468)
#
# factor(state)TN               -0.133
#                               (0.468)
#
# factor(state)TX               -0.783
#                               (0.468)
#
# factor(state)UT                0.233
#                               (0.468)
#
# factor(state)VA              -1.183**
#                               (0.468)
#
# factor(state)VT              -1.133**
#                               (0.468)
#
# factor(state)WA               -0.067
#                               (0.468)
#
# factor(state)WI               -0.217
#                               (0.468)
#
# factor(state)WV                0.267
#                               (0.468)
#
# factor(state)WY               -0.683
#                               (0.468)
#
# Constant                     3.133***
#                               (0.354)
#
# -----------------------------------------------
# Observations                    102
# R2                             0.760
# Adjusted R2                    0.514
# Residual Std. Error       0.433 (df = 50)
# F Statistic           3.097*** (df = 51; 50)
# ===============================================
# Note:               *p<0.1; **p<0.05; ***p<0.01

# %% [markdown]
# ## 4. Standard Errors for Fixed Effects Regression
# * robust
# * cluster s.d.

# %%
library(lmtest)
library(sandwich)
FE <- plm(dthrte ~ open, data = traffic1, index = c("state", "year"), model = "within")

coeftest(FE, vcovHC(FE, type = 'HC1'))
# robust
# Out:
# t test of coefficients:
#
#      Estimate Std. Error t value  Pr(>|t|)
# open -0.96667    0.10940 -8.8358 8.721e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(FE, vcovHC(FE, type = 'HC0', cluster = 'group'))
# cluster
# Out:
# t test of coefficients:
#
#      Estimate Std. Error t value  Pr(>|t|)
# open -0.96667    0.10887 -8.8794 7.489e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
